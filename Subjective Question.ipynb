# %% [markdown]
# ### <a style="color:red">Question:</a>
# #### What is the optimal value of alpha for ridge and lasso regression? What will be the changes in the model if you choose double the value of alpha for both ridge and lasso? What will be the most important predictor variables after the change is implemented?

# %% [markdown]
# ### Answer :
#
# #### Ridge Regression : optimal lambda : 10 , on double the value of alpha i.e. 20 train r2 score decreases from 87 to 86 and test r2 score decreases from 85 to 84
#
# Top 10 feature of Ridge
# with alpha 10:
# ![image.png](attachment:image.png)
#
# with alpha 20:
# ![image-2.png](attachment:image-2.png)
#
# it shows that top feature remain same but coefficent get changed
#
# #### Lasso Regression : optimal lambda : 0.001 on double the value of alpha i.e. 0.002 train r2 score decreases from 83 to 77 and test r2 score decreases from 81 to 77
#
# Top 10 feature of Lasso
# with alpha .001:
# ![image-6.png](attachment:image-6.png)
#
# with alpha .002:
# ![image-5.png](attachment:image-5.png)
#
# it shows that top feature get changed as well coefficent also get changed

# %% [markdown]
# ### <a style="color:red">Question:</a>
# #### You have determined the optimal value of lambda for ridge and lasso regression during the assignment. Now, which one will you choose to apply and why?

# %% [markdown]
# #### Optimal value for lambda is chossen on best param value of the lambda based on the GridCV and estimator r2 ( gridCV will give mean r2 score across the n Fold) , we also analyse the Train & test score of the model based on the the lambda value selected ( optimal value), and it should not vary much as it may lead to underfit or overfit.
#
# #### best param : model_cv.best_params_
# #### best score : model_cv.best_score_
#
# Ridge Regression : optimal lambda : 10 &&
# Lasso Regression : optimal lambda : 0.001

# %% [markdown]
# ### <a style="color:red">Question:</a>
#
# #### After building the model, you realised that the five most important predictor variables in the lasso model are not available in the incoming data. You will now have to create another model excluding the five most important predictor variables. Which are the five most important predictor variables now?

# %% [markdown]
# #### Answer:
# Five most imp variable in Lasso with lambda 0.001 is  'GrLivArea','OverallQual_9','OverallQual_10','GarageCars','Neighborhood_NoRidge'
#
# ![image.png](attachment:image.png)
#
# Lets remove these variable and rebuild the lasso model and next set of five most imp feature is
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### <a style="color:red">Question:</a>
#
# #### How can you make sure that a model is robust and generalisable? What are the implications of the same for the accuracy of the model and why?

# %% [markdown]
# #### Answer :
# Regularization helps to avoid overfiiting  as well underfitting, keeping bias & variance trade off at its best.
#
# #### A model that exhibits small variance and high bias will underfit the target, while a model with high variance and little bias will overfit the target. A model with high variance may represent the data set accurately but could lead to overfitting to noisy or otherwise unrepresentative training data
#
# #### implications of the same for the accuracy of the model : train & test accuracy does not vary much and its differnece is within permissible range because model is prevented from the underfit & overfit
